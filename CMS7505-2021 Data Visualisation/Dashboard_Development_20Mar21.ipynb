# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd

import plotly.io as pio
pio.templates.default="simple_white"

# %%
MASTER_IMPORT=pd.read_csv("CanadaCO2Data_Clean.csv",index_col=0)

# %%
MASTER_IMPORT
# Out:
#            Make            Model Vehicle Class  Engine Size(L)  Cylinders  \
# 705       MAZDA           MAZDA2       COMPACT             1.5          4
# 1017     TOYOTA            YARIS       COMPACT             1.5          4
# 2138     TOYOTA            YARIS       COMPACT             1.5          4
# 3257     TOYOTA  YARIS HATCHBACK       COMPACT             1.5          4
# 4321     TOYOTA  YARIS HATCHBACK       COMPACT             1.5          4
# ...         ...              ...           ...             ...        ...
# 4565  CHEVROLET         CORVETTE    TWO-SEATER             6.2          8
# 4567  CHEVROLET     CORVETTE Z06    TWO-SEATER             6.2          8
# 5628  CHEVROLET         Corvette    TWO-SEATER             6.2          8
# 5630  CHEVROLET     Corvette Z06    TWO-SEATER             6.2          8
# 5632  CHEVROLET     Corvette ZR1    TWO-SEATER             6.2          8
#
#      Transmission         Fuel Type  Fuel Consumption City (L/100 km)  \
# 705     Automatic  Regular Gasoline                               8.4
# 1017    Automatic  Regular Gasoline                               7.9
# 2138    Automatic  Regular Gasoline                               7.8
# 3257    Automatic  Regular Gasoline                               7.8
# 4321    Automatic  Regular Gasoline                               7.9
# ...           ...               ...                               ...
# 4565       Manual  Premium Gasoline                              14.2
# 4567       Manual  Premium Gasoline                              15.6
# 5628       Manual  Premium Gasoline                              14.6
# 5630       Manual  Premium Gasoline                              15.9
# 5632       Manual  Premium Gasoline                              18.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 705                               6.9                               7.7
# 1017                              6.6                               7.3
# 2138                              6.6                               7.3
# 3257                              6.6                               7.3
# 4321                              6.8                               7.4
# ...                               ...                               ...
# 4565                              9.0                              11.9
# 4567                             10.6                              13.4
# 5628                              9.3                              12.2
# 5630                             10.6                              13.5
# 5632                             12.5                              15.6
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)  Gears
# 705                            37                  177    4.0
# 1017                           39                  168    4.0
# 2138                           39                  168    4.0
# 3257                           39                  170    4.0
# 4321                           38                  173    4.0
# ...                           ...                  ...    ...
# 4565                           24                  278    7.0
# 4567                           21                  312    7.0
# 5628                           23                  286    7.0
# 5630                           21                  318    7.0
# 5632                           18                  368    7.0
#
# [7385 rows x 13 columns]

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options

fig = px.box(MASTER_IMPORT, x="Transmission", y="CO2 Emissions(g/km)", color="Fuel Type")

app.layout = html.Div(children=[
    html.H1(children='Hello Dash'),

    html.Div(children='''
        Dash: A web application framework for Python.
    '''),

    dcc.Graph(
        id='example-graph',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=True,use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
